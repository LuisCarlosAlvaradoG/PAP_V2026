# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ____

# %%
PATH_DATE_DEF = "Tablero de trabajo(Fechas de Semanas).csv"
PATH_CONCEPT_CLASQ = "Tablero de trabajo(Clasificacion de Conceptos).csv"
PATH_CASH_FLOW = "Tablero de trabajo(Flujos de E).csv"

# %%
df_dates = pd.read_csv(PATH_DATE_DEF, encoding='latin-1', sep=';', quotechar='"')

# %%
df_dates
# Out:
#       Semanas        Fechas
# 0    Semana 1     10-15 Nov
# 1    Semana 2     17-22 Nov
# 2    Semana 3     24-29 Nov
# 3    Semana 4       1-6 Dic
# 4    Semana 5      8-13 Dic
# 5    Semana 6     15-20 Dic
# 6    Semana 7     21-27 Dic
# 7    Semana 8  29 Dic-3 Ene
# 8    Semana 9      5-10 Ene
# 9   Semana 10     11-17 Ene
# 10  Semana 11     19-24 Ene
# 11  Semana 12     26-31 Ene
# 12  Semana 13       1-7 Feb
# 13  Semana 14      9-14 Feb
# 14  Semana 15     16-21 Feb
# 15  Semana 16     23-28 Feb
# 16  Semana 17       2-7 Mar
# 17  Semana 18      9-14 Mar
# 18  Semana 19     16-21 Mar
# 19  Semana 20     23-28 Mar
# 20  Semana 21  30 Mar-4 Abr
# 21  Semana 22      6-11 Abr
# 22  Semana 23     13-18 Abr
# 23  Semana 24     20-25 Abr
# 24  Semana 25  27 Abr-2 May
# 25  Semana 26       4-9 May
# 26  Semana 27     11-16 May
# 27  Semana 28     18-23 May
# 28  Semana 29     25-30 May

# %%
df_cash_flow = pd.read_csv(PATH_CASH_FLOW, encoding='latin-1', sep=';', quotechar='"')
conceptos = df.iloc[0, 1:]
df_cash_flow = df_cash_flow.T
datos = df.iloc[1:, 1:]
semanas = df.iloc[1:, 0]

# %%
df_cash_flow
# Out:
#                               0                                      1    \
# Conceptos    ALEJANDRO RODRIGUEZ    Responsabilidad ALEJANDRO RODRIGUEZ
# Semana 1                      NaN                                    NaN
# Semana 2                      NaN                                    NaN
# Semana 3                      NaN                                    NaN
# Semana 4                      NaN                                    NaN
# Semana 5                      NaN                                    NaN
# Semana 6                      NaN                                    NaN
# Semana 7                      NaN                                    NaN
# Semana 8                      NaN                                    NaN
# Semana 9                      NaN                                    NaN
# Semana 10                     NaN                                    NaN
# Semana 11                     NaN                                    NaN
# Semana 12                     NaN                                    NaN
# Semana 13                     NaN                                    NaN
# Semana 14                     NaN                                    NaN
# Semana 15             $20.000,00                                     NaN
# Semana 16                     NaN                                    NaN
# Semana 17                     NaN                                    NaN
# Semana 18             $20.000,00                                     NaN
# Semana 19                     NaN                                    NaN
# Semana 20                     NaN                            $20.000,00
# Semana 21             $20.000,00                                     NaN
# Semana 22                     NaN                                    NaN
# Semana 23                     NaN                                    NaN
# Semana 24                     NaN                                    NaN
# Semana 25                     NaN                                    NaN
# Semana 26                     NaN                                    NaN
# Semana 27                     NaN                                    NaN
# Semana 28                     NaN                                    NaN
# Semana 29                     NaN                                    NaN
#
#                       2                      3              4    \
# Conceptos            AVV    Responsabilidad AVV    Aceros Gutz
# Semana 1              NaN                    NaN            NaN
# Semana 2              NaN                    NaN            NaN
# Semana 3              NaN                    NaN            NaN
# Semana 4              NaN                    NaN            NaN
# Semana 5     $280.000,00             $85.000,00             NaN
# Semana 6      $83.200,00                     NaN            NaN
# Semana 7     $260.435,00                     NaN            NaN
# Semana 8              NaN                    NaN            NaN
# Semana 9              NaN                    NaN            NaN
# Semana 10             NaN                    NaN            NaN
# Semana 11             NaN                    NaN            NaN
# Semana 12             NaN                    NaN            NaN
# Semana 13             NaN                    NaN            NaN
# Semana 14             NaN                    NaN            NaN
# Semana 15             NaN            $15.000,00             NaN
# Semana 16      $6.500,00              $6.500,00             NaN
# Semana 17             NaN                    NaN            NaN
# Semana 18             NaN                    NaN            NaN
# Semana 19             NaN                    NaN            NaN
# Semana 20     $50.000,00                     NaN            NaN
# Semana 21             NaN            $50.000,00             NaN
# Semana 22             NaN            $50.000,00             NaN
# Semana 23             NaN                    NaN            NaN
# Semana 24             NaN                    NaN            NaN
# Semana 25             NaN                    NaN     $1.076,00
# Semana 26             NaN                    NaN            NaN
# Semana 27             NaN                    NaN            NaN
# Semana 28             NaN                    NaN            NaN
# Semana 29     $11.000,00                     NaN            NaN
#
#                                       5              6    \
# Conceptos    Responsabilidad Aceros Gutz    Alex y Rafa
# Semana 1                              NaN    $10.000,00
# Semana 2                              NaN    $20.000,00
# Semana 3                              NaN            NaN
# Semana 4                              NaN    $10.000,00
# Semana 5                              NaN    $10.000,00
# Semana 6                              NaN    $10.000,00
# Semana 7                              NaN            NaN
# Semana 8                              NaN    $10.000,00
# Semana 9                              NaN            NaN
# Semana 10                             NaN            NaN
# Semana 11                             NaN            NaN
# Semana 12                             NaN    $15.000,00
# Semana 13                             NaN    $20.000,00
# Semana 14                             NaN            NaN
# Semana 15                             NaN    $19.999,80
# Semana 16                             NaN    $10.000,00
# Semana 17                             NaN            NaN
# Semana 18                             NaN            NaN
# Semana 19                             NaN            NaN
# Semana 20                             NaN    $10.000,00
# Semana 21                             NaN            NaN
# Semana 22                             NaN            NaN
# Semana 23                             NaN    $10.000,00
# Semana 24                             NaN            NaN
# Semana 25                             NaN    $10.000,00
# Semana 26                             NaN            NaN
# Semana 27                             NaN    $10.000,00
# Semana 28                             NaN            NaN
# Semana 29                             NaN    $10.000,00
#
#                                       7                  8    \
# Conceptos    Responsabilidad Alex y Rafa    Arturo Guerrero
# Semana 1                              NaN        $30.000,00
# Semana 2                              NaN        $50.000,00
# Semana 3                      $20.000,00                 NaN
# Semana 4                              NaN        $50.000,00
# Semana 5                              NaN                NaN
# Semana 6                              NaN        $50.000,00
# Semana 7                      $15.000,00         $60.000,00
# Semana 8                              NaN                NaN
# Semana 9                      $15.000,00                 NaN
# Semana 10                     $15.000,00                 NaN
# Semana 11                             NaN                NaN
# Semana 12                             NaN                NaN
# Semana 13                             NaN                NaN
# Semana 14                     $19.999,80                 NaN
# Semana 15                     $10.000,00                 NaN
# Semana 16                     $10.000,00                 NaN
# Semana 17                     $10.000,00                 NaN
# Semana 18                     $10.000,00                 NaN
# Semana 19                     $10.000,00                 NaN
# Semana 20                             NaN                NaN
# Semana 21                     $10.000,00                 NaN
# Semana 22                     $10.000,00                 NaN
# Semana 23                             NaN                NaN
# Semana 24                     $10.000,00                 NaN
# Semana 25                             NaN                NaN
# Semana 26                     $10.000,00                 NaN
# Semana 27                     $10.000,00                 NaN
# Semana 28                     $10.000,00                 NaN
# Semana 29                             NaN                NaN
#
#                                           9                           10   \
# Conceptos    Responsabilidad Arturo Guerrero    BATAS, DIESEL, HOMEDEPOT
# Semana 1                                  NaN                         NaN
# Semana 2                                  NaN                         NaN
# Semana 3                          $50.000,00                          NaN
# Semana 4                                  NaN                         NaN
# Semana 5                          $50.000,00                          NaN
# Semana 6                                  NaN                         NaN
# Semana 7                                  NaN                         NaN
# Semana 8                                  NaN                         NaN
# Semana 9                                  NaN                         NaN
# Semana 10                                 NaN                         NaN
# Semana 11                                 NaN                         NaN
# Semana 12                                 NaN                         NaN
# Semana 13                                 NaN                         NaN
# Semana 14                                 NaN                         NaN
# Semana 15                                 NaN                         NaN
# Semana 16                                 NaN                         NaN
# Semana 17                                 NaN                         NaN
# Semana 18                                 NaN                         NaN
# Semana 19                                 NaN                         NaN
# Semana 20                                 NaN                         NaN
# Semana 21                                 NaN                         NaN
# Semana 22                                 NaN                         NaN
# Semana 23                                 NaN                         NaN
# Semana 24                                 NaN                         NaN
# Semana 25                                 NaN                         NaN
# Semana 26                                 NaN                         NaN
# Semana 27                                 NaN                  $4.674,00
# Semana 28                                 NaN                         NaN
# Semana 29                                 NaN                         NaN
#
#                                                    11                  12   \
# Conceptos    Responsabilidad BATAS, DIESEL, HOMEDEPOT    Bolsa (Chavinda)
# Semana 1                                           NaN                 NaN
# Semana 2                                           NaN                 NaN
# Semana 3                                           NaN                 NaN
# Semana 4                                           NaN                 NaN
# Semana 5                                           NaN                 NaN
# Semana 6                                           NaN                 NaN
# Semana 7                                           NaN                 NaN
# Semana 8                                           NaN                 NaN
# Semana 9                                           NaN                 NaN
# Semana 10                                          NaN                 NaN
# Semana 11                                          NaN                 NaN
# Semana 12                                          NaN                 NaN
# Semana 13                                          NaN                 NaN
# Semana 14                                          NaN                 NaN
# Semana 15                                          NaN          $7.250,00
# Semana 16                                          NaN          $7.250,00
# Semana 17                                          NaN                 NaN
# Semana 18                                          NaN                 NaN
# Semana 19                                          NaN                 NaN
# Semana 20                                          NaN                 NaN
# Semana 21                                          NaN                 NaN
# Semana 22                                          NaN                 NaN
# Semana 23                                          NaN                 NaN
# Semana 24                                          NaN         $18.000,00
# Semana 25                                          NaN                 NaN
# Semana 26                                          NaN                 NaN
# Semana 27                                          NaN                 NaN
# Semana 28                                          NaN                 NaN
# Semana 29                                          NaN                 NaN
#
#                                            13   \
# Conceptos    Responsabilidad Bolsa (Chavinda)
# Semana 1                                   NaN
# Semana 2                                   NaN
# Semana 3                                   NaN
# Semana 4                                   NaN
# Semana 5                                   NaN
# Semana 6                                   NaN
# Semana 7                                   NaN
# Semana 8                                   NaN
# Semana 9                                   NaN
# Semana 10                           $8.460,60
# Semana 11                                  NaN
# Semana 12                           $8.700,00
# Semana 13                                  NaN
# Semana 14                           $5.800,00
# Semana 15                                  NaN
# Semana 16                                  NaN
# Semana 17                           $7.250,00
# Semana 18                           $7.250,00
# Semana 19                           $7.250,00
# Semana 20                           $7.250,00
# Semana 21                           $7.250,00
# Semana 22                           $7.250,00
# Semana 23                           $7.250,00
# Semana 24                                  NaN
# Semana 25                                  NaN
# Semana 26                                  NaN
# Semana 27                                  NaN
# Semana 28                                  NaN
# Semana 29                                  NaN
#
#                                         14   \
# Conceptos    Bolsa Transparente (Chavinda)
# Semana 1                                NaN
# Semana 2                                NaN
# Semana 3                                NaN
# Semana 4                                NaN
# Semana 5                                NaN
# Semana 6                         $8.000,00
# Semana 7                                NaN
# Semana 8                                NaN
# Semana 9                                NaN
# Semana 10                               NaN
# Semana 11                               NaN
# Semana 12                               NaN
# Semana 13                               NaN
# Semana 14                               NaN
# Semana 15                               NaN
# Semana 16                               NaN
# Semana 17                               NaN
# Semana 18                               NaN
# Semana 19                               NaN
# Semana 20                               NaN
# Semana 21                               NaN
# Semana 22                               NaN
# Semana 23                               NaN
# Semana 24                               NaN
# Semana 25                               NaN
# Semana 26                               NaN
# Semana 27                               NaN
# Semana 28                               NaN
# Semana 29                               NaN
#
#                                                         15   \
# Conceptos    Responsabilidad Bolsa Transparente (Chavinda)
# Semana 1                                                NaN
# Semana 2                                                NaN
# Semana 3                                                NaN
# Semana 4                                         $7.350,00
# Semana 5                                         $7.350,00
# Semana 6                                         $7.350,00
# Semana 7                                         $8.000,00
# Semana 8                                                NaN
# Semana 9                                                NaN
# Semana 10                                               NaN
# Semana 11                                               NaN
# Semana 12                                               NaN
# Semana 13                                               NaN
# Semana 14                                               NaN
# Semana 15                                               NaN
# Semana 16                                               NaN
# Semana 17                                               NaN
# Semana 18                                               NaN
# Semana 19                                               NaN
# Semana 20                                               NaN
# Semana 21                                               NaN
# Semana 22                                               NaN
# Semana 23                                               NaN
# Semana 24                                               NaN
# Semana 25                                               NaN
# Semana 26                                               NaN
# Semana 27                                               NaN
# Semana 28                                               NaN
# Semana 29                                               NaN
#
#                                   16   \
# Conceptos    CAJA CARTON (PATAGONIA)
# Semana 1                          NaN
# Semana 2                          NaN
# Semana 3                          NaN
# Semana 4                          NaN
# Semana 5                  $19.604,00
# Semana 6                  $39.208,00
# Semana 7                          NaN
# Semana 8                          NaN
# Semana 9                          NaN
# Semana 10                         NaN
# Semana 11                 $20.697,60
# Semana 12                  $9.802,00
# Semana 13                         NaN
# Semana 14                         NaN
# Semana 15                  $9.802,00
# Semana 16                  $9.802,00
# Semana 17                  $1.896,60
# Semana 18                         NaN
# Semana 19                         NaN
# Semana 20                         NaN
# Semana 21                         NaN
# Semana 22                  $9.135,00
# Semana 23                 $18.270,00
# Semana 24                 $38.541,00
# Semana 25                 $29.899,00
# Semana 26                 $18.270,00
# Semana 27                 $65.847,40
# Semana 28                 $14.697,20
# Semana 29                 $54.740,40
#
#                                                   17               18   \
# Conceptos    Responsabilidad CAJA CARTON (PATAGONIA)    CAJA RUTH GDL
# Semana 1                                          NaN              NaN
# Semana 2                                          NaN              NaN
# Semana 3                                          NaN              NaN
# Semana 4                                          NaN              NaN
# Semana 5                                          NaN              NaN
# Semana 6                                          NaN              NaN
# Semana 7                                          NaN              NaN
# Semana 8                                          NaN              NaN
# Semana 9                                          NaN              NaN
# Semana 10                                 $38.144,00               NaN
# Semana 11                                         NaN              NaN
# Semana 12                                         NaN              NaN
# Semana 13                                  $9.802,00       $44.000,00
# Semana 14                                         NaN      $33.328,91
# Semana 15                                         NaN              NaN
# Semana 16                                         NaN              NaN
# Semana 17                                 $15.549,80       $20.000,00
# Semana 18                                         NaN              NaN
# Semana 19                                         NaN              NaN
# Semana 20                                         NaN              NaN
# Semana 21                                         NaN              NaN
# Semana 22                                         NaN              NaN
# Semana 23                                  $9.135,00       $30.000,00
# Semana 24                                         NaN      $31.642,40
# Semana 25                                         NaN              NaN
# Semana 26                                         NaN              NaN
# Semana 27                                         NaN              NaN
# Semana 28                                         NaN              NaN
# Semana 29                                         NaN              NaN
#
#                                         19                            20   \
# Conceptos    Responsabilidad CAJA RUTH GDL    CHRISTIAN MANUEL (TAMINAS)
# Semana 1                                NaN                           NaN
# Semana 2                                NaN                           NaN
# Semana 3                                NaN                           NaN
# Semana 4                                NaN                           NaN
# Semana 5                                NaN                           NaN
# Semana 6                                NaN                           NaN
# Semana 7                                NaN                           NaN
# Semana 8                                NaN                           NaN
# Semana 9                                NaN                           NaN
# Semana 10                       $20.000,00                            NaN
# Semana 11                               NaN                           NaN
# Semana 12                               NaN                           NaN
# Semana 13                               NaN                           NaN
# Semana 14                        $9.280,00                            NaN
# Semana 15                       $42.000,00                            NaN
# Semana 16                       $42.000,00                            NaN
# Semana 17                       $28.477,37                            NaN
# Semana 18                       $28.477,37                            NaN
# Semana 19                       $61.642,40                            NaN
# Semana 20                       $61.642,40                            NaN
# Semana 21                       $61.642,40                            NaN
# Semana 22                       $61.642,40                            NaN
# Semana 23                       $61.642,40                            NaN
# Semana 24                               NaN                           NaN
# Semana 25                               NaN                           NaN
# Semana 26                       $20.000,00                            NaN
# Semana 27                       $77.738,85                            NaN
# Semana 28                       $77.738,85                     $1.044,00
# Semana 29                       $77.738,85                            NaN
#
#                                                      21                 22   \
# Conceptos    Responsabilidad CHRISTIAN MANUEL (TAMINAS)    CIELO (TARIMAS)
# Semana 1                                             NaN                NaN
# Semana 2                                             NaN                NaN
# Semana 3                                             NaN                NaN
# Semana 4                                             NaN                NaN
# Semana 5                                             NaN                NaN
# Semana 6                                             NaN                NaN
# Semana 7                                             NaN         $8.120,00
# Semana 8                                             NaN                NaN
# Semana 9                                             NaN                NaN
# Semana 10                                            NaN                NaN
# Semana 11                                            NaN                NaN
# Semana 12                                            NaN                NaN
# Semana 13                                            NaN                NaN
# Semana 14                                            NaN                NaN
# Semana 15                                            NaN                NaN
# Semana 16                                            NaN                NaN
# Semana 17                                            NaN                NaN
# Semana 18                                            NaN                NaN
# Semana 19                                            NaN                NaN
# Semana 20                                            NaN                NaN
# Semana 21                                            NaN                NaN
# Semana 22                                            NaN                NaN
# Semana 23                                            NaN                NaN
# Semana 24                                            NaN                NaN
# Semana 25                                            NaN                NaN
# Semana 26                                            NaN                NaN
# Semana 27                                            NaN                NaN
# Semana 28                                            NaN                NaN
# Semana 29                                            NaN                NaN
#
#                                           23           24   \
# Conceptos    Responsabilidad CIELO (TARIMAS)        CIPSA
# Semana 1                                  NaN   $3.000,00
# Semana 2                          $16.240,00    $3.000,00
# Semana 3                                  NaN          NaN
# Semana 4                                  NaN   $2.784,00
# Semana 5                                  NaN          NaN
# Semana 6                                  NaN          NaN
# Semana 7                                  NaN   $5.568,00
# Semana 8                                  NaN          NaN
# Semana 9                                  NaN          NaN
# Semana 10                         $15.660,00           NaN
# Semana 11                                 NaN          NaN
# Semana 12                         $16.240,00           NaN
# Semana 13                                 NaN          NaN
# Semana 14                                 NaN          NaN
# Semana 15                                 NaN          NaN
# Semana 16                                 NaN          NaN
# Semana 17                                 NaN          NaN
# Semana 18                                 NaN          NaN
# Semana 19                                 NaN   $3.828,00
# Semana 20                                 NaN          NaN
# Semana 21                                 NaN          NaN
# Semana 22                                 NaN   $2.784,00
# Semana 23                         $32.480,00           NaN
# Semana 24                                 NaN          NaN
# Semana 25                         $32.480,00    $2.784,00
# Semana 26                         $32.480,00           NaN
# Semana 27                         $32.480,00           NaN
# Semana 28                         $32.480,00           NaN
# Semana 29                         $32.480,00           NaN
#
#                                 25           26                       27   \
# Conceptos    Responsabilidad CIPSA        CIRAM    Responsabilidad CIRAM
# Semana 1                        NaN          NaN                      NaN
# Semana 2                        NaN          NaN                      NaN
# Semana 3                 $3.000,00           NaN                      NaN
# Semana 4                 $3.000,00           NaN                      NaN
# Semana 5                 $5.568,00           NaN                      NaN
# Semana 6                 $5.568,00           NaN                      NaN
# Semana 7                        NaN          NaN                      NaN
# Semana 8                        NaN          NaN                      NaN
# Semana 9                        NaN          NaN                      NaN
# Semana 10                       NaN          NaN                      NaN
# Semana 11                       NaN          NaN                      NaN
# Semana 12                       NaN          NaN                      NaN
# Semana 13                       NaN          NaN                      NaN
# Semana 14                       NaN          NaN                      NaN
# Semana 15                       NaN          NaN                      NaN
# Semana 16                       NaN          NaN                      NaN
# Semana 17                       NaN          NaN                      NaN
# Semana 18                       NaN          NaN                      NaN
# Semana 19                       NaN          NaN                      NaN
# Semana 20                       NaN          NaN                      NaN
# Semana 21                       NaN          NaN                      NaN
# Semana 22                       NaN   $3.795,02                       NaN
# Semana 23                $2.784,00           NaN               $3.795,01
# Semana 24                $2.784,00           NaN               $3.795,01
# Semana 25                       NaN   $3.795,01                       NaN
# Semana 26                       NaN          NaN                      NaN
# Semana 27                $3.886,00           NaN               $6.050,00
# Semana 28                $3.886,00           NaN                      NaN
# Semana 29                $3.886,00           NaN                      NaN
#
#                            28                                  29   \
# Conceptos    CODICE ETIQUETAS    Responsabilidad CODICE ETIQUETAS
# Semana 1                   NaN                                 NaN
# Semana 2                   NaN                                 NaN
# Semana 3                   NaN                                 NaN
# Semana 4                   NaN                                 NaN
# Semana 5                   NaN                                 NaN
# Semana 6            $3.648,39                                  NaN
# Semana 7                   NaN                                 NaN
# Semana 8                   NaN                                 NaN
# Semana 9            $3.981,94                                  NaN
# Semana 10                  NaN                                 NaN
# Semana 11                  NaN                                 NaN
# Semana 12                  NaN                                 NaN
# Semana 13                  NaN                                 NaN
# Semana 14                  NaN                                 NaN
# Semana 15                  NaN                                 NaN
# Semana 16                  NaN                                 NaN
# Semana 17           $2.868,00                           $2.868,00
# Semana 18                  NaN                                 NaN
# Semana 19                  NaN                                 NaN
# Semana 20                  NaN                                 NaN
# Semana 21                  NaN                                 NaN
# Semana 22                  NaN                                 NaN
# Semana 23                  NaN                                 NaN
# Semana 24                  NaN                                 NaN
# Semana 25                  NaN                                 NaN
# Semana 26                  NaN                                 NaN
# Semana 27                  NaN                          $3.596,65
# Semana 28                  NaN                          $3.596,65
# Semana 29           $4.172,11                                  NaN
#
#                         30                               31   \
# Conceptos    COMPRA LAPTOP    Responsabilidad COMPRA LAPTOP
# Semana 1                NaN                              NaN
# Semana 2                NaN                              NaN
# Semana 3                NaN                              NaN
# Semana 4                NaN                              NaN
# Semana 5                NaN                              NaN
# Semana 6                NaN                              NaN
# Semana 7                NaN                              NaN
# Semana 8                NaN                              NaN
# Semana 9                NaN                              NaN
# Semana 10               NaN                              NaN
# Semana 11               NaN                              NaN
# Semana 12               NaN                              NaN
# Semana 13               NaN                              NaN
# Semana 14               NaN                              NaN
# Semana 15               NaN                              NaN
# Semana 16               NaN                              NaN
# Semana 17               NaN                              NaN
# Semana 18               NaN                              NaN
# Semana 19        $7.499,00                               NaN
# Semana 20               NaN                              NaN
# Semana 21               NaN                              NaN
# Semana 22               NaN                              NaN
# Semana 23               NaN                              NaN
# Semana 24               NaN                              NaN
# Semana 25               NaN                              NaN
# Semana 26               NaN                              NaN
# Semana 27               NaN                              NaN
# Semana 28               NaN                              NaN
# Semana 29               NaN                              NaN
#
#                                        32   \
# Conceptos    CONTRATO REIMER (Lic Carlos)
# Semana 1                               NaN
# Semana 2                               NaN
# Semana 3                               NaN
# Semana 4                               NaN
# Semana 5                               NaN
# Semana 6                               NaN
# Semana 7                               NaN
# Semana 8                        $9.280,00
# Semana 9                               NaN
# Semana 10                              NaN
# Semana 11                              NaN
# Semana 12                              NaN
# Semana 13                              NaN
# Semana 14                              NaN
# Semana 15                              NaN
# Semana 16                              NaN
# Semana 17                              NaN
# Semana 18                              NaN
# Semana 19                              NaN
# Semana 20                              NaN
# Semana 21                              NaN
# Semana 22                              NaN
# Semana 23                              NaN
# Semana 24                              NaN
# Semana 25                              NaN
# Semana 26                              NaN
# Semana 27                              NaN
# Semana 28                              NaN
# Semana 29                              NaN
#
#                                                        33   \
# Conceptos    Responsabilidad CONTRATO REIMER (Lic Carlos)
# Semana 1                                               NaN
# Semana 2                                               NaN
# Semana 3                                               NaN
# Semana 4                                               NaN
# Semana 5                                               NaN
# Semana 6                                               NaN
# Semana 7                                               NaN
# Semana 8                                               NaN
# Semana 9                                               NaN
# Semana 10                                              NaN
# Semana 11                                              NaN
# Semana 12                                              NaN
# Semana 13                                              NaN
# Semana 14                                              NaN
# Semana 15                                              NaN
# Semana 16                                              NaN
# Semana 17                                              NaN
# Semana 18                                              NaN
# Semana 19                                              NaN
# Semana 20                                              NaN
# Semana 21                                              NaN
# Semana 22                                              NaN
# Semana 23                                              NaN
# Semana 24                                              NaN
# Semana 25                                              NaN
# Semana 26                                              NaN
# Semana 27                                              NaN
# Semana 28                                              NaN
# Semana 29                                              NaN
#
#                             34                                   35   \
# Conceptos    CONVENIO IMSS CXM    Responsabilidad CONVENIO IMSS CXM
# Semana 1                    NaN                                  NaN
# Semana 2                    NaN                                  NaN
# Semana 3                    NaN                                  NaN
# Semana 4                    NaN                                  NaN
# Semana 5                    NaN                                  NaN
# Semana 6                    NaN                                  NaN
# Semana 7                    NaN                                  NaN
# Semana 8                    NaN                                  NaN
# Semana 9                    NaN                                  NaN
# Semana 10                   NaN                                  NaN
# Semana 11                   NaN                                  NaN
# Semana 12                   NaN                                  NaN
# Semana 13                   NaN                                  NaN
# Semana 14                   NaN                                  NaN
# Semana 15                   NaN                                  NaN
# Semana 16                   NaN                                  NaN
# Semana 17                   NaN                                  NaN
# Semana 18                   NaN                                  NaN
# Semana 19                   NaN                                  NaN
# Semana 20                   NaN                                  NaN
# Semana 21                   NaN                                  NaN
# Semana 22                   NaN                                  NaN
# Semana 23                   NaN                          $32.000,00
# Semana 24                   NaN                                  NaN
# Semana 25                   NaN                                  NaN
# Semana 26                   NaN                                  NaN
# Semana 27                   NaN                                  NaN
# Semana 28                   NaN                                  NaN
# Semana 29                   NaN                                  NaN
#
#                           36                                 37   \
# Conceptos    Contador Carlos    Responsabilidad Contador Carlos
# Semana 1                  NaN                                NaN
# Semana 2                  NaN                                NaN
# Semana 3                  NaN                                NaN
# Semana 4          $10.000,00                                 NaN
# Semana 5                  NaN                                NaN
# Semana 6                  NaN                                NaN
# Semana 7                  NaN                                NaN
# Semana 8                  NaN                                NaN
# Semana 9                  NaN                                NaN
# Semana 10                 NaN                                NaN
# Semana 11                 NaN                                NaN
# Semana 12                 NaN                                NaN
# Semana 13                 NaN                                NaN
# Semana 14                 NaN                                NaN
# Semana 15                 NaN                                NaN
# Semana 16                 NaN                                NaN
# Semana 17                 NaN                                NaN
# Semana 18                 NaN                                NaN
# Semana 19                 NaN                                NaN
# Semana 20                 NaN                                NaN
# Semana 21                 NaN                                NaN
# Semana 22                 NaN                                NaN
# Semana 23                 NaN                                NaN
# Semana 24                 NaN                                NaN
# Semana 25                 NaN                                NaN
# Semana 26                 NaN                                NaN
# Semana 27                 NaN                                NaN
# Semana 28                 NaN                                NaN
# Semana 29                 NaN                                NaN
#
#                             38                                   39   \
# Conceptos    Contador Raymundo    Responsabilidad Contador Raymundo
# Semana 1                    NaN                                  NaN
# Semana 2                    NaN                           $3.000,00
# Semana 3                    NaN                                  NaN
# Semana 4                    NaN                                  NaN
# Semana 5                    NaN                                  NaN
# Semana 6                    NaN                                  NaN
# Semana 7             $2.000,00                                   NaN
# Semana 8                    NaN                                  NaN
# Semana 9                    NaN                                  NaN
# Semana 10                   NaN                                  NaN
# Semana 11                   NaN                                  NaN
# Semana 12                   NaN                                  NaN
# Semana 13                   NaN                                  NaN
# Semana 14                   NaN                                  NaN
# Semana 15                   NaN                                  NaN
# Semana 16                   NaN                                  NaN
# Semana 17                   NaN                                  NaN
# Semana 18                   NaN                                  NaN
# Semana 19                   NaN                                  NaN
# Semana 20                   NaN                                  NaN
# Semana 21                   NaN                                  NaN
# Semana 22                   NaN                                  NaN
# Semana 23                   NaN                                  NaN
# Semana 24                   NaN                                  NaN
# Semana 25                   NaN                                  NaN
# Semana 26                   NaN                                  NaN
# Semana 27                   NaN                                  NaN
# Semana 28                   NaN                                  NaN
# Semana 29                   NaN                                  NaN
#
#                            40                                  41        42   \
# Conceptos    Cristian Ramirez    Responsabilidad Cristian Ramirez    DELFIN
# Semana 1                   NaN                                 NaN       NaN
# Semana 2                   NaN                         $25.800,00        NaN
# Semana 3                   NaN                                 NaN       NaN
# Semana 4                   NaN                                 NaN       NaN
# Semana 5                   NaN                                 NaN       NaN
# Semana 6           $38.700,00                                  NaN       NaN
# Semana 7           $28.500,00                          $22.800,00        NaN
# Semana 8                   NaN                         $22.800,00        NaN
# Semana 9                   NaN                         $32.388,28        NaN
# Semana 10                  NaN                         $37.000,00        NaN
# Semana 11                  NaN                                 NaN       NaN
# Semana 12                  NaN                         $54.000,00        NaN
# Semana 13                  NaN                         $28.500,00        NaN
# Semana 14          $28.500,00                                  NaN       NaN
# Semana 15                  NaN                                 NaN       NaN
# Semana 16                  NaN                                 NaN       NaN
# Semana 17                  NaN                         $28.500,00        NaN
# Semana 18                  NaN                         $28.500,00        NaN
# Semana 19                  NaN                                 NaN       NaN
# Semana 20                  NaN                                 NaN       NaN
# Semana 21                  NaN                                 NaN       NaN
# Semana 22                  NaN                                 NaN       NaN
# Semana 23                  NaN                                 NaN       NaN
# Semana 24                  NaN                                 NaN       NaN
# Semana 25                  NaN                                 NaN       NaN
# Semana 26                  NaN                                 NaN       NaN
# Semana 27                  NaN                                 NaN       NaN
# Semana 28                  NaN                                 NaN       NaN
# Semana 29                  NaN                                 NaN       NaN
#
#                                  43           44                       45   \
# Conceptos    Responsabilidad DELFIN        DIKEN    Responsabilidad DIKEN
# Semana 1                         NaN          NaN                      NaN
# Semana 2                         NaN          NaN                      NaN
# Semana 3                         NaN          NaN                      NaN
# Semana 4                         NaN          NaN                      NaN
# Semana 5                         NaN          NaN                      NaN
# Semana 6                         NaN          NaN                      NaN
# ...
# Semana 9                                      NaN
# Semana 10                                     NaN
# Semana 11                                     NaN
# Semana 12                                     NaN
# Semana 13                                     NaN
# Semana 14                                     NaN
# Semana 15                                     NaN
# Semana 16                                     NaN
# Semana 17                                     NaN
# Semana 18                                     NaN
# Semana 19                                     NaN
# Semana 20                                     NaN
# Semana 21                                     NaN
# Semana 22                                     NaN
# Semana 23                                     NaN
# Semana 24                                     NaN
# Semana 25                                     NaN
# Semana 26                                     NaN
# Semana 27                                     NaN
# Semana 28                                     NaN
# Semana 29                                     NaN
#
#                                         162  \
# Conceptos    Varios (Llaves reparacion FV)
# Semana 1                                NaN
# Semana 2                                NaN
# Semana 3                                NaN
# Semana 4                                NaN
# Semana 5                                NaN
# Semana 6                                NaN
# Semana 7                                NaN
# Semana 8                                NaN
# Semana 9                                NaN
# Semana 10                               NaN
# Semana 11                               NaN
# Semana 12                               NaN
# Semana 13                               NaN
# Semana 14                               NaN
# Semana 15                               NaN
# Semana 16                               NaN
# Semana 17                               NaN
# Semana 18                               NaN
# Semana 19                               NaN
# Semana 20                               NaN
# Semana 21                               NaN
# Semana 22                               NaN
# Semana 23                               NaN
# Semana 24                               NaN
# Semana 25                          $520,00
# Semana 26                               NaN
# Semana 27                               NaN
# Semana 28                               NaN
# Semana 29                               NaN
#
#                                                         163       164  \
# Conceptos    Responsabilidad Varios (Llaves reparacion FV)    gastos
# Semana 1                                                NaN       NaN
# Semana 2                                                NaN       NaN
# Semana 3                                                NaN       NaN
# Semana 4                                                NaN       NaN
# Semana 5                                                NaN       NaN
# Semana 6                                                NaN       NaN
# Semana 7                                                NaN       NaN
# Semana 8                                                NaN       NaN
# Semana 9                                                NaN       NaN
# Semana 10                                               NaN       NaN
# Semana 11                                               NaN       NaN
# Semana 12                                               NaN       NaN
# Semana 13                                               NaN       NaN
# Semana 14                                               NaN       NaN
# Semana 15                                               NaN       NaN
# Semana 16                                               NaN       NaN
# Semana 17                                               NaN       NaN
# Semana 18                                               NaN       NaN
# Semana 19                                               NaN       NaN
# Semana 20                                               NaN       NaN
# Semana 21                                               NaN       NaN
# Semana 22                                               NaN       NaN
# Semana 23                                               NaN       NaN
# Semana 24                                               NaN       NaN
# Semana 25                                               NaN       NaN
# Semana 26                                               NaN       NaN
# Semana 27                                               NaN       NaN
# Semana 28                                               NaN       NaN
# Semana 29                                               NaN       NaN
#
#                                  165           166  \
# Conceptos    Responsabilidad gastos      telefono
# Semana 1                         NaN           NaN
# Semana 2                         NaN           NaN
# Semana 3                         NaN           NaN
# Semana 4                         NaN           NaN
# Semana 5                         NaN           NaN
# Semana 6                         NaN           NaN
# Semana 7                         NaN   $12.000,00
# Semana 8                         NaN           NaN
# Semana 9                         NaN           NaN
# Semana 10                        NaN           NaN
# Semana 11                        NaN           NaN
# Semana 12                $10.000,00            NaN
# Semana 13                        NaN           NaN
# Semana 14                        NaN           NaN
# Semana 15                        NaN           NaN
# Semana 16                        NaN           NaN
# Semana 17                        NaN           NaN
# Semana 18                        NaN           NaN
# Semana 19                        NaN           NaN
# Semana 20                        NaN           NaN
# Semana 21                        NaN           NaN
# Semana 22                        NaN           NaN
# Semana 23                        NaN           NaN
# Semana 24                        NaN           NaN
# Semana 25                        NaN           NaN
# Semana 26                        NaN           NaN
# Semana 27                        NaN           NaN
# Semana 28                        NaN           NaN
# Semana 29                        NaN           NaN
#
#                                    167              168             169  \
# Conceptos    Responsabilidad telefono    Omar Guerrero    Gera Armenta
# Semana 1                           NaN     $175.500,80              NaN
# Semana 2                           NaN              NaN    $105.000,00
# Semana 3                           NaN              NaN             NaN
# Semana 4                           NaN              NaN             NaN
# Semana 5                           NaN              NaN             NaN
# Semana 6                           NaN              NaN             NaN
# Semana 7                           NaN              NaN             NaN
# Semana 8                           NaN              NaN             NaN
# Semana 9                           NaN              NaN             NaN
# Semana 10                          NaN              NaN             NaN
# Semana 11                          NaN              NaN             NaN
# Semana 12                          NaN              NaN             NaN
# Semana 13                          NaN              NaN             NaN
# Semana 14                          NaN              NaN             NaN
# Semana 15                          NaN              NaN             NaN
# Semana 16                          NaN              NaN             NaN
# Semana 17                          NaN              NaN             NaN
# Semana 18                          NaN              NaN             NaN
# Semana 19                          NaN              NaN             NaN
# Semana 20                          NaN              NaN             NaN
# Semana 21                          NaN              NaN             NaN
# Semana 22                          NaN              NaN             NaN
# Semana 23                          NaN              NaN             NaN
# Semana 24                          NaN              NaN             NaN
# Semana 25                          NaN              NaN             NaN
# Semana 26                          NaN              NaN             NaN
# Semana 27                          NaN              NaN             NaN
# Semana 28                          NaN              NaN             NaN
# Semana 29                          NaN              NaN             NaN
#
#                      170           171            172            173  \
# Conceptos          Gaby        Cuenta       Proberry         Reimer
# Semana 1             NaN   $48.000,00             NaN            NaN
# Semana 2             NaN   $60.000,00             NaN            NaN
# Semana 3     $12.000,00    $40.000,00             NaN            NaN
# Semana 4     $12.000,00    $40.000,00             NaN            NaN
# Semana 5             NaN           NaN   $401.720,00             NaN
# Semana 6             NaN           NaN   $381.000,00             NaN
# Semana 7             NaN           NaN   $194.026,80    $400.000,00
# Semana 8             NaN           NaN   $198.000,00             NaN
# Semana 9             NaN           NaN   $168.444,80             NaN
# Semana 10            NaN           NaN   $252.468,28             NaN
# Semana 11            NaN           NaN   $165.824,00             NaN
# Semana 12            NaN           NaN   $321.376,00             NaN
# Semana 13            NaN           NaN   $249.424,00             NaN
# Semana 14            NaN           NaN   $190.680,00             NaN
# Semana 15            NaN           NaN   $437.300,00             NaN
# Semana 16            NaN           NaN   $227.100,00             NaN
# Semana 17            NaN           NaN   $328.790,00             NaN
# Semana 18            NaN           NaN   $328.790,00             NaN
# Semana 19            NaN           NaN   $328.790,00             NaN
# Semana 20            NaN           NaN   $203.456,00             NaN
# Semana 21            NaN           NaN   $132.880,00             NaN
# Semana 22            NaN           NaN   $199.760,00             NaN
# Semana 23            NaN           NaN   $126.412,00             NaN
# Semana 24            NaN           NaN   $247.412,00             NaN
# Semana 25            NaN           NaN   $333.976,00             NaN
# Semana 26            NaN           NaN   $193.267,80             NaN
# Semana 27            NaN           NaN   $328.464,00             NaN
# Semana 28            NaN           NaN            NaN            NaN
# Semana 29            NaN           NaN   $184.700,00             NaN
#
#                      174            175           176                     177  \
# Conceptos          GALU       Efectivo     Saldo LAR    Prestamo Embolsadora
# Semana 1             NaN    $80.000,00            NaN                     NaN
# Semana 2             NaN   $130.000,00            NaN                     NaN
# Semana 3             NaN    $86.000,00            NaN                     NaN
# Semana 4             NaN    $86.000,00            NaN                     NaN
# Semana 5             NaN    $44.750,00            NaN                     NaN
# Semana 6             NaN            NaN           NaN                     NaN
# Semana 7             NaN     $1.000,00            NaN                     NaN
# Semana 8             NaN            NaN           NaN                     NaN
# Semana 9             NaN    $53.100,00            NaN                     NaN
# Semana 10    $39.947,52             NaN           NaN                     NaN
# Semana 11            NaN    $47.000,00            NaN                     NaN
# Semana 12            NaN            NaN           NaN                     NaN
# Semana 13            NaN            NaN           NaN                     NaN
# Semana 14            NaN            NaN   $30.000,00              $80.000,00
# Semana 15            NaN            NaN           NaN                     NaN
# Semana 16            NaN            NaN           NaN                     NaN
# Semana 17            NaN            NaN           NaN                     NaN
# Semana 18            NaN            NaN           NaN                     NaN
# Semana 19            NaN            NaN           NaN                     NaN
# Semana 20            NaN            NaN           NaN                     NaN
# Semana 21            NaN            NaN           NaN                     NaN
# Semana 22            NaN            NaN           NaN                     NaN
# Semana 23            NaN            NaN           NaN                     NaN
# Semana 24            NaN            NaN           NaN                     NaN
# Semana 25            NaN            NaN           NaN                     NaN
# Semana 26            NaN            NaN           NaN                     NaN
# Semana 27            NaN            NaN           NaN                     NaN
# Semana 28            NaN            NaN           NaN                     NaN
# Semana 29            NaN            NaN           NaN                     NaN
#
#                       178              179             180              181
# Conceptos       Pago AVV    Mauricio Caro    Pago Luinni     Crumble otros
# Semana 1              NaN              NaN             NaN              NaN
# Semana 2              NaN              NaN             NaN              NaN
# Semana 3              NaN              NaN             NaN              NaN
# Semana 4              NaN              NaN             NaN              NaN
# Semana 5              NaN              NaN             NaN              NaN
# Semana 6              NaN              NaN             NaN              NaN
# Semana 7              NaN              NaN             NaN              NaN
# Semana 8              NaN              NaN             NaN              NaN
# Semana 9              NaN              NaN             NaN              NaN
# Semana 10             NaN              NaN             NaN              NaN
# Semana 11             NaN              NaN             NaN              NaN
# Semana 12             NaN              NaN             NaN              NaN
# Semana 13             NaN              NaN             NaN              NaN
# Semana 14             NaN              NaN             NaN              NaN
# Semana 15             NaN              NaN             NaN              NaN
# Semana 16             NaN              NaN             NaN              NaN
# Semana 17             NaN              NaN             NaN              NaN
# Semana 18             NaN              NaN             NaN              NaN
# Semana 19             NaN              NaN             NaN              NaN
# Semana 20             NaN              NaN             NaN              NaN
# Semana 21             NaN              NaN             NaN              NaN
# Semana 22             NaN              NaN             NaN              NaN
# Semana 23    $130.000,00               NaN             NaN              NaN
# Semana 24             NaN     $277.461,40              NaN              NaN
# Semana 25             NaN              NaN             NaN              NaN
# Semana 26             NaN              NaN             NaN              NaN
# Semana 27             NaN              NaN     $25.000,00               NaN
# Semana 28             NaN              NaN             NaN     $206.448,00
# Semana 29             NaN              NaN             NaN     $127.000,00

# %%
df_concepts = pd.read_csv(PATH_CONCEPT_CLASQ, encoding='latin-1', sep=';', quotechar='"')

# %%
df_concepts
# Out:
#                      Pintura FV ( cubeta Esmalte)                Operación  \
# 0    Responsabilidad Pintura FV ( cubeta Esmalte)                Operación
# 1                                         Platano                Operación
# 2                         Responsabilidad Platano                Operación
# 3                                           RAISA                Operación
# 4                           Responsabilidad RAISA                Operación
# 5                                   ROBERTO REYES                Operación
# 6                   Responsabilidad ROBERTO REYES                Operación
# 7                                      ROCIO IMPI                Operación
# 8                      Responsabilidad ROCIO IMPI                Operación
# 9                            SAM JARABES TAPATIOS                Operación
# 10           Responsabilidad SAM JARABES TAPATIOS                Operación
# 11                                       SANICHEM                Operación
# 12                       Responsabilidad SANICHEM                Operación
# 13                                    SEGURO AVEO                Operación
# 14                    Responsabilidad SEGURO AVEO                Operación
# 15                             SIMA (Calibracion)                Operación
# 16             Responsabilidad SIMA (Calibracion)                Operación
# 17                                       SINDULFO                Operación
# 18                       Responsabilidad SINDULFO                Operación
# 19                                     SR IGNACIO                Operación
# 20                     Responsabilidad SR IGNACIO                Operación
# 21                           STEREN NEBULIZADORES                Operación
# 22           Responsabilidad STEREN NEBULIZADORES                Operación
# 23                                         TARIMA                Operación
# 24                         Responsabilidad TARIMA                Operación
# 25                                   TRAMITES CFE     Obligaciones Legales
# 26                   Responsabilidad TRAMITES CFE     Obligaciones Legales
# 27                                   TRES GUERRAS                Operación
# 28                   Responsabilidad TRES GUERRAS                Operación
# 29                                      Tenencias     Obligaciones Legales
# 30                      Responsabilidad Tenencias     Obligaciones Legales
# 31                            Transporte de Gente                Operación
# 32            Responsabilidad Transporte de Gente                Operación
# 33                            VERIFICACION FLOSOL     Obligaciones Legales
# 34            Responsabilidad VERIFICACION FLOSOL     Obligaciones Legales
# 35                  Varios (Llaves reparacion FV)                Operación
# 36  Responsabilidad Varios (Llaves reparacion FV)                Operación
# 37                                         gastos                Operación
# 38                         Responsabilidad gastos                Operación
# 39                                       telefono                Operación
# 40                       Responsabilidad telefono                Operación
# 41                                  Omar Guerrero      Ingresos Operativos
# 42                                   Gera Armenta      Ingresos Operativos
# 43                                           Gaby      Ingresos Operativos
# 44                                         Cuenta      Ingresos Operativos
# 45                                       Proberry      Ingresos Operativos
# 46                                         Reimer      Ingresos Operativos
# 47                                           GALU      Ingresos Operativos
# 48                                       Efectivo      Ingresos Operativos
# 49                                      Saldo LAR  Transferencias Internas
# 50                           Prestamo Embolsadora     Ingresos Financieros
# 51                                       Pago AVV      Ingresos Operativos
# 52                                  Mauricio Caro      Ingresos Operativos
# 53                                    Pago Luinni      Ingresos Operativos
# 54                                  Crumble otros   Ingresos No Operativos
#
#                           Gastos de Operación
# 0      Responsabilidad de Gastos de Operación
# 1                         Gastos de Operación
# 2      Responsabilidad de Gastos de Operación
# 3                         Gastos de Operación
# 4      Responsabilidad de Gastos de Operación
# 5                      Sueldos y Prestaciones
# 6   Responsabilidad de Sueldos y Prestaciones
# 7                      Sueldos y Prestaciones
# 8   Responsabilidad de Sueldos y Prestaciones
# 9                         Gastos de Operación
# 10     Responsabilidad de Gastos de Operación
# 11                        Gastos de Operación
# 12     Responsabilidad de Gastos de Operación
# 13                        Gastos de Operación
# 14     Responsabilidad de Gastos de Operación
# 15                        Gastos de Operación
# 16     Responsabilidad de Gastos de Operación
# 17                     Sueldos y Prestaciones
# 18  Responsabilidad de Sueldos y Prestaciones
# 19                     Sueldos y Prestaciones
# 20  Responsabilidad de Sueldos y Prestaciones
# 21                        Gastos de Operación
# 22     Responsabilidad de Gastos de Operación
# 23                        Gastos de Operación
# 24     Responsabilidad de Gastos de Operación
# 25                       Impuestos y Gobierno
# 26    Responsabilidad de Impuestos y Gobierno
# 27                        Gastos de Operación
# 28     Responsabilidad de Gastos de Operación
# 29                       Impuestos y Gobierno
# 30    Responsabilidad de Impuestos y Gobierno
# 31                        Gastos de Operación
# 32     Responsabilidad de Gastos de Operación
# 33                       Impuestos y Gobierno
# 34    Responsabilidad de Impuestos y Gobierno
# 35                        Gastos de Operación
# 36     Responsabilidad de Gastos de Operación
# 37                        Gastos de Operación
# 38     Responsabilidad de Gastos de Operación
# 39                        Gastos de Operación
# 40     Responsabilidad de Gastos de Operación
# 41                                     Ventas
# 42                                     Ventas
# 43                                     Ventas
# 44                                     Ventas
# 45                                     Ventas
# 46                                     Ventas
# 47                                     Ventas
# 48                                     Ventas
# 49                       Movimientos Internos
# 50                                  Préstamos
# 51                    Recuperación de Cuentas
# 52                                     Ventas
# 53                    Recuperación de Cuentas
# 54                             Otros Ingresos

# %% [markdown]
# ___

# %% [markdown]
# #### Revisión de la Deuda

# %%
def convertir_moneda(valor):
    if pd.isna(valor):
        return np.nan
    if isinstance(valor, (int, float)):
        return float(valor)
    try:
        limpio = str(valor).replace('$', '').replace('.', '').replace(',', '.')
        return float(limpio)
    except:
        return np.nan

columna_conceptos = df_cash_flow.T.columns[0]
semanas = df_cash_flow.T.columns[1:].tolist()

mask = df_cash_flow.T[columna_conceptos].str.strip().str.startswith('Responsabilidad', na=False)
df_resp = df_cash_flow.T.loc[mask].copy()

if df_resp.empty:
    print("⚠️ No se encontraron filas que empiecen con 'Responsabilidad'.")
    print("💡 Revisa los primeros valores de la columna:")
    print(df_cash_flow[columna_conceptos].head(10).tolist())
else:
    for col in semanas:
        if col in df_resp.columns:
            df_resp[col] = df_resp[col].apply(convertir_moneda)

    df_resp['Total_Concepto'] = df_resp[semanas].sum(axis=1, skipna=True)
    total_general = df_resp['Total_Concepto'].sum()
    df_resp['Porcentaje'] = (df_resp['Total_Concepto'] / total_general) * 100

    print("💰 TOTAL GENERAL DE DEUDA (solo Responsabilidad)")
    print("=" * 60)
    print(f"$ {total_general:,.2f}".replace(',', '.').replace('.', ',', 1))

    print("\n" + "=" * 60)
    print("📊 DETALLE POR CONCEPTO (solo con deuda > 0, ordenado por % DESC)")
    print("=" * 60)

    resultado = df_resp[[columna_conceptos, 'Total_Concepto', 'Porcentaje']]

    resultado = resultado[resultado['Total_Concepto'].notna() & (resultado['Total_Concepto'] > 0)]

    resultado = resultado.sort_values('Porcentaje', ascending=False)

    if resultado.empty:
        print("⚠️ No hay conceptos con deuda > 0.")
    else:
        print(resultado.to_string(index=False, formatters={
            'Total_Concepto': lambda x: f"$ {x:,.2f}".replace(',', '.').replace('.', ',', 1),
            'Porcentaje': lambda x: f"{x:.4f} %"
        }))
# Out:
# 💰 TOTAL GENERAL DE DEUDA (solo Responsabilidad)
# ============================================================
# $ 5,251.847.13
#
# ============================================================
# 📊 DETALLE POR CONCEPTO (solo con deuda > 0, ordenado por % DESC)
# ============================================================
#                                                      Conceptos  Total_Concepto Porcentaje
#                                  Responsabilidad CAJA RUTH GDL    $ 731,663.29  13.9315 %
#                                       Responsabilidad SINDULFO    $ 453,982.40   8.6442 %
#                                          Responsabilidad RAISA    $ 439,241.00   8.3636 %
#                                           Responsabilidad GALU    $ 436,000.00   8.3018 %
#                                      Responsabilidad Nomina FV    $ 314,500.00   5.9884 %
#                               Responsabilidad Cristian Ramirez    $ 280,288.28   5.3369 %
#                                           Responsabilidad IMSS    $ 280,000.00   5.3315 %
#                                  Responsabilidad ROBERTO REYES    $ 257,891.20   4.9105 %
#                                Responsabilidad CIELO (TARIMAS)    $ 243,020.00   4.6273 %
#                                            Responsabilidad AVV    $ 206,500.00   3.9319 %
#                                    Responsabilidad Alex y Rafa    $ 194,999.80   3.7130 %
#                                       Responsabilidad IMSS CXM    $ 159,593.54   3.0388 %
#                 Responsabilidad JOSE HDEZ GARCIA (PAGO TARIMA)    $ 153,700.00   2.9266 %
#                      Responsabilidad Ing Aguilar , embolsadora    $ 129,534.00   2.4664 %
#                                Responsabilidad Arturo Guerrero    $ 100,000.00   1.9041 %
#                                           Responsabilidad LORE     $ 87,650.00   1.6689 %
#                               Responsabilidad Bolsa (Chavinda)     $ 73,710.60   1.4035 %
#                        Responsabilidad CAJA CARTON (PATAGONIA)     $ 72,630.80   1.3830 %
#                               Responsabilidad Despacho Garnica     $ 62,856.90   1.1969 %
#                                     Responsabilidad Nomina CXM     $ 46,400.00   0.8835 %
#                                   Responsabilidad LALO AGUIRRE     $ 45,692.50   0.8700 %
#                         Responsabilidad GLADYS (CERTIFICACION)     $ 45,000.00   0.8568 %
#                            Responsabilidad Honorarios contador     $ 39,918.56   0.7601 %
#                                          Responsabilidad CIPSA     $ 34,362.00   0.6543 %
#                                         Responsabilidad TARIMA     $ 32,480.00   0.6184 %
#             Responsabilidad Edgar Joel Vega Martínez (Emplaye)     $ 32,329.49   0.6156 %
#                              Responsabilidad CONVENIO IMSS CXM     $ 32,000.00   0.6093 %
#                  Responsabilidad Bolsa Transparente (Chavinda)     $ 30,050.00   0.5722 %
#                                       Responsabilidad EMBAPACK     $ 26,883.00   0.5119 %
#                                       Responsabilidad SANICHEM     $ 26,646.80   0.5074 %
#                                       Responsabilidad EFECTIVO     $ 20,000.00   0.3808 %
#                             Responsabilidad SIMA (Calibracion)     $ 20,000.00   0.3808 %
#                       Responsabilidad NOMINA JACONA Y OCUMICHO     $ 20,000.00   0.3808 %
#                            Responsabilidad ALEJANDRO RODRIGUEZ     $ 20,000.00   0.3808 %
#                                          Responsabilidad CIRAM     $ 13,640.02   0.2597 %
#                                  Responsabilidad IMPUESTOS LAR     $ 13,428.00   0.2557 %
#                            Responsabilidad Transporte de Gente     $ 12,000.00   0.2285 %
#                                  Responsabilidad NOMINA JACONA     $ 10,800.00   0.2056 %
#                               Responsabilidad CODICE ETIQUETAS     $ 10,061.30   0.1916 %
#                                         Responsabilidad gastos     $ 10,000.00   0.1904 %
#                          Responsabilidad IMPUESTOS OCTUBRE LAR      $ 7,900.00   0.1504 %
#                                          Responsabilidad DIKEN      $ 7,285.36   0.1387 %
#                                     Responsabilidad PRIMUS LAB      $ 6,086.26   0.1159 %
#  Responsabilidad PLATANO 1A/2A RECEPCION (12/11/25)/(14/11/25)      $ 5,253.25   0.1000 %
#                              Responsabilidad Contador Raymundo      $ 3,000.00   0.0571 %
#                                    Responsabilidad SEGURO AVEO      $ 2,028.84   0.0386 %
#                                        Responsabilidad PROLIZA        $ 593,50   0.0113 %
#                                         Responsabilidad DELFIN        $ 246,44   0.0047 %

# %% [markdown]
# ____

# %% [markdown]
# #### Modelo Propuesto

# %% [markdown]
# $
# \min_{t} \sum \left[
# \sum_{i} x_{i} D_{i,t}
# + \beta \max(0, L_{min} - C_{t})
# \right]
# $
#
# ##### Restricciones/Sujeto a:
# * _Liquidez_: $C_t ≥ L_{min}$
# * _No negatividad de caja_: $C_t \geq 0$
# * _Dinámica de caja_:$C_t = C_{t-1} + U_t - \sum_j p_{j,t}$
# * _Dinámica de deuda_:$D_{j,t} = D_{j,t-1} - p_{j,t}$
# * _Restricción de pagos por deuda_:$0 \leq p_{j,t} \leq D_{j,t}$
# * _No negatividad de deuda_:$D_{j,t} \geq 0$
# * _Restricción de pagos:_ $\sum_j p_{j,t} \leq C_t$
# * _Pago de Impuetos_: $I_{pago} = I_{total}$
#
# Ut​=It​−Et​−∑j​pj,t​≥0

# %% [markdown]
# $1.$
# <br>$E_t = G_t^{\text{oper}}$
# <br>
# $2.$
# <br>$R_t = I_t+C_t-G_t^{\text{oper}}$
# <br>$C_t^{\text{new}} = \min(L_{min},R_t )$
# <br>
# $3.$
# <br>$P_t^{\text{total}} = \max(0, R_t - L_{min})$
# <br>
# $4.$
# <br>$\min \sum_{t=1}^{\text{T}}\sum_i x_i D_{i,t}$

# %% [markdown]
# ____

# %% [markdown]
# #### Implementación

# %%
LIQUIDEZ = 200000
CAJA = 1500000

COEF_ALPHA = 1 
COEF_BETA = 1

# %% [markdown]
# ____
